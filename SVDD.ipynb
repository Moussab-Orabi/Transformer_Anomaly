# %%
y_train.shape
# Out:
# (140, 1)

# %%
import sys
sys.path.append("..")
from sklearn.datasets import load_wine
from src.BaseSVDD import BaseSVDD, BananaDataset

# Banana-shaped dataset generation and partitioning
X, y = BananaDataset.generate(number=100, display='on')
X_train, X_test, y_train, y_test = BananaDataset.split(X, y, ratio=0.3)


# 
svdd = BaseSVDD(C=0.9, gamma=0.3, kernel='rbf', display='on')

# 
svdd.fit(X_train,  y_train)

# 
svdd.plot_boundary(X_train,  y_train)

#
y_test_predict = svdd.predict(X_test, y_test)

# #
radius = svdd.radius
distance = svdd.get_distance(X_test)
svdd.plot_distance(radius, distance)
# Out:
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 0.0332 seconds
# kernel function      = rbf
# iterations           = 11
# number of samples    = 140
# number of features   = 2
# number of SVs        = 14
# ratio of SVs         = 10.0000 %
# accuracy             = 90.7143 %
#
#
# Calculating the grid scores (0050*0050)...
#
# Calculation of the grid scores is completed. Time cost 0.1007 seconds
# *** Prediction of the provided data is completed. ***
#
# running time         = 0.0000 seconds
# number of samples    = 60
# number of alarm      = 37
# accuracy             = 88.3333 %

# %%
# !pip install cvxopt
# Out:
# Requirement already satisfied: cvxopt in c:\users\m_orabi\anaconda3\lib\site-packages (1.3.2)

# %%
import sys
sys.path.append("..")
from sklearn.datasets import load_wine
from src.BaseSVDD import BaseSVDD, BananaDataset

# Banana-shaped dataset generation and partitioning
X, y = BananaDataset.generate(number=100, display='on')
X_train, X_test, y_train, y_test = BananaDataset.split(X, y, ratio=0.3)


# 
svdd = BaseSVDD(C=0.9, gamma=0.3, kernel='rbf', display='on')

# 
svdd.fit(X_train,  y_train)

# 
svdd.plot_boundary(X_train,  y_train)

#
y_test_predict = svdd.predict(X_test, y_test)

# #
radius = svdd.radius
distance = svdd.get_distance(X_test)
svdd.plot_distance(radius, distance)
# Out:
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 0.0353 seconds
# kernel function      = rbf
# iterations           = 10
# number of samples    = 140
# number of features   = 2
# number of SVs        = 12
# ratio of SVs         = 8.5714 %
# accuracy             = 97.8571 %
#
#
# Calculating the grid scores (0050*0050)...
#
# Calculation of the grid scores is completed. Time cost 0.0988 seconds
# *** Prediction of the provided data is completed. ***
#
# running time         = 0.0000 seconds
# number of samples    = 60
# number of alarm      = 32
# accuracy             = 96.6667 %

# %% [markdown]
# # unlabeled data

# %%
# -*- coding: utf-8 -*-
"""

An example for SVDD model fitting with negataive samples

"""
import sys
sys.path.append("..")
import numpy as np
from src.BaseSVDD import BaseSVDD

# create 100 points with 2 dimensions
n = 100
dim = 2
X = np.r_[np.random.randn(n, dim)]

# svdd object using rbf kernel
svdd = BaseSVDD(C=0.9, gamma=0.3, kernel='rbf', display='on')

# fit the SVDD model
svdd.fit(X)

# predict the label
y_predict = svdd.predict(X)

# plot the boundary
svdd.plot_boundary(X)

# plot the distance
radius = svdd.radius
distance = svdd.get_distance(X)
svdd.plot_distance(radius, distance)
# Out:
# *** Fitting of the SVDD model is completed. ***
#
# running time         = 0.0206 seconds
# kernel function      = rbf
# iterations           = 11
# number of samples    = 100
# number of features   = 2
# number of SVs        = 11
# ratio of SVs         = 11.0000 %
# accuracy             = 90.0000 %
#
#
#
#
# *** Prediction of the provided data is completed. ***
#
# running time         = 0.0000 seconds
# number of samples    = 100
# number of alarm      = 10
#
#
# Calculating the grid scores (0050*0050)...
# Calculation of the grid scores is completed. Time cost 0.1217 seconds

# %%
# read the data
import pandas as pd

# %%
df_train = pd.read_csv('8844578_final_20102022_train.csv')
df_test = pd.read_csv('8844578_final_20102022_test.csv')
df_train_y=pd.read_csv('8844578_final_20102022_train_y.csv')
df_test_y=pd.read_csv('8844578_final_20102022_test_y.csv')

# %%
df_train_y.value_counts()
# Out:
# Class
# 1        2332
# 0          21
# dtype: int64

# %%
df_train.columns
# Out:
# Index(['BMWNumber', 'Month', 'Processed_hour', 'ProductID',
#        'Processed_hour_sin', 'WeldingWay', 'WeldPosAfterRPN', 'Shift_elapsed',
#        'Tool', 'DMC', 'Nacharbeit', 'Dayofyear', 'MachineID', 'Is_weekend',
#        'WeldTime', 'ProductName', 'MachineName', 'Dayofweek', 'Week',
#        'Processed_hour_cos', 'Elapsed_to_last_bad_DMC', 'WeldPower', 'Shift',
#        'WeldTriggerPoint', 'WeldAmplitude'],
#       dtype='object')

# %%
X=df_train[['WeldTime','WeldPower','WeldAmplitude']].values

# %%
# -*- coding: utf-8 -*-
"""

An example for SVDD model fitting with negataive samples

"""
import sys
sys.path.append("..")
import numpy as np
from src.BaseSVDD import BaseSVDD

# create 100 points with 2 dimensions
# n = 100
# dim = 2
# X = np.r_[np.random.randn(n, dim)]

# svdd object using rbf kernel
svdd = BaseSVDD(C=0.9, gamma=0.3, kernel='rbf', display='on')

# fit the SVDD model
svdd.fit(X)

# predict the label
y_predict = svdd.predict(X)

# plot the boundary
svdd.plot_boundary(X)

# plot the distance
radius = svdd.radius
distance = svdd.get_distance(X)
svdd.plot_distance(radius, distance)

# %%
.shape
# Out:
# (2353, 2)

# %%
radius.shape
# Out:
# ()

# %%
# plot the boundary
svdd.plot_boundary(X[:,:2])

# # plot the distance
# radius = svdd.radius
# distance = svdd.get_distance(X[:,:2])
# svdd.plot_distance(radius, distance)

# %%
y=y_predict.reshape(y_predict.shape[0],).astype(int)

# %%
df_train_y.shape, y.shape
# Out:
# ((2353, 2), (2353,))

# %%
df_train_y['predict']=y

# %%
df_train_y['predict']=df_train_y['predict'].apply(lambda x: 1 if x==1 else 0)

# %%
from sklearn import metrics
import matplotlib.pyplot as plt

confusion_matrix = metrics.confusion_matrix(df_train_y['Class'], df_train_y['predict'])

# %%
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
cm_display.plot()
plt.show()
